# %%
import pandas as pd
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
# # bring in the 311 data

# data311_df = pd.read_csv("../Clean Data Files/modelstartdata.csv")


# print(data311_df.columns.values)
# # print(data311_df["sr create date"])
# data311_df.head()
# Out:
# ['index' 'case number' 'sr location' 'county' 'district' 'neighborhood'
#  'tax id' 'trash quad' 'recycle quad' 'trash day' 'heavy trash day'
#  'recycle day' 'key map' 'management district' 'department' 'division'
#  'sr type' 'queue' 'sla' 'status' 'sr create date' 'due date'
#  'date closed' 'overdue' 'title' 'x' 'y' 'latitude' 'longitude'
#  'channel type' 'zipcode' 'openclosetime' 'openduetime' 'year']
#    index            case number                      sr location  county  \
# 0      6  12091836-101002444730      3303 SAGE, HOUSTON TX 77056  HARRIS
# 1     12  12091839-101002444736  7701 APPLETON, HOUSTON TX 77022  HARRIS
# 2     13  12091840-101002444737  7701 APPLETON, HOUSTON TX 77022  HARRIS
# 3     15  12091841-101002444739  7612 APPLETON, HOUSTON TX 77022  HARRIS
# 4     23  12091843-101002444752  7335 IWO JIMA, HOUSTON TX 77033  HARRIS
#
#   district         neighborhood        tax id trash quad recycle quad  \
# 0        G       GREATER UPTOWN  4.514000e+11        NaN          NaN
# 1        H  NORTHSIDE/NORTHLINE  7.102100e+11         NE           NW
# 2        H  NORTHSIDE/NORTHLINE  4.200500e+11         NE           NW
# 3        H  NORTHSIDE/NORTHLINE  7.102100e+11         NE           NW
# 4        D           SOUTH PARK  7.518900e+11         SE           SE
#
#   trash day  ...                          title            x            y  \
# 0       NaN  ...        Water Leak-101002444730  3089853.524  13831195.74
# 1    MONDAY  ...  Sewer Wastewater-101002444736  3119884.277  13867666.56
# 2    MONDAY  ...     Water Service-101002444737  3119785.781  13867661.60
# 3    MONDAY  ...     Water Service-101002444739  3120069.146  13867375.14
# 4    FRIDAY  ...        Water Leak-101002444752  3128978.891  13812277.81
#
#     latitude  longitude channel type zipcode               openclosetime  \
# 0  29.733522 -95.466104     Voice In   77056  32 days 12:49:18.000000000
# 1  29.831239 -95.367955     Voice In   77022   3 days 05:37:27.000000000
# 2  29.831234 -95.368266     Voice In   77022   2 days 22:16:31.000000000
# 3  29.830423 -95.367401     Voice In   77022   0 days 02:26:29.000000000
# 4  29.678215 -95.344744     Voice In   77033   0 days 02:34:10.000000000
#
#                   openduetime  year
# 0   9 days 23:59:59.000000000  2017
# 1   0 days 23:59:58.000000000  2017
# 2   2 days 00:00:00.000000000  2017
# 3   1 days 23:59:59.000000000  2017
# 4  10 days 00:00:00.000000000  2017
#
# [5 rows x 34 columns]

# %%
# ################################################################
# # create a date value formatted the same as the weather data

# splitdate = data311_df["sr create date"].str.split(" ", n=1, expand=True)

# data311_df["create_date"] = splitdate[0]
# data311_df["create_date"] = pd.to_datetime(data311_df["create_date"])
# data311_df["create_date"] = data311_df['create_date'].dt.strftime('%Y-%m-%d')

# ##################################################################
# # below is where I create the variables that I can use for modeling. I originally was trying to use the openclose time
# # columns, but couldn't get it to just show the number of days.

# data311.head()

# type(data311_df["sr create date"])

# # I set these as date formats using the to_datetime

# data311_df["create_date_time"] = pd.to_datetime(data311_df["sr create date"])
# data311_df["date_closed_time"] = pd.to_datetime(data311_df["date closed"])
# data311_df["due_date_time"] = pd.to_datetime(data311_df["due date"])


# # here  I define weather is was closed by the due date (0) or not (1)
# data311_df["missed_due_date"] = np.where(data311_df["due_date_time"] > data311_df["date_closed_time"], 0, 1)

# # calculate the difference between the closed date at the create date
# data311_df["time_to_close"] = data311_df["date_closed_time"] - data311_df["create_date_time"]

# # apply formatting so that is is in seconds. then calculate the number of days.
# data311_df["seconds_to_close"] = data311_df["time_to_close"].astype('timedelta64[s]')
# data311_df["days_to_close"] = data311_df["seconds_to_close"]/60/60/24
 
# # data311_df[["create_date_time", "date_closed_time", "time_to_close","seconds_to_close", "days_to_close"]]


# data311_df[["create_date_time","due_date_time", "date_closed_time", "missed_due_date", "days_to_close"]]
# Out:
#        create_date_time       due_date_time    date_closed_time  \
# 0   2017-01-01 00:30:00 2017-01-11 00:30:00 2017-02-02 13:20:00
# 1   2017-01-01 05:22:00 2017-01-02 05:22:00 2017-01-04 11:00:00
# 2   2017-01-01 05:23:00 2017-01-03 05:23:00 2017-01-04 03:40:00
# 3   2017-01-01 06:43:00 2017-01-03 06:43:00 2017-01-01 09:10:00
# 4   2017-01-01 08:45:00 2017-01-11 08:45:00 2017-01-01 11:20:00
# 5   2017-01-01 09:49:00 2017-01-02 09:49:00 2017-01-01 12:00:00
# 6   2017-01-01 10:23:00 2017-01-11 10:23:00 2017-01-01 12:55:00
# 7   2017-01-01 10:30:00 2017-01-02 10:30:00 2017-01-12 02:50:00
# 8   2017-01-01 10:56:00 2017-01-02 10:56:00 2017-01-02 16:10:00
# 9   2017-01-01 11:04:00 2017-01-02 11:04:00 2017-01-04 03:35:00
# 10  2017-01-01 11:07:00 2017-01-11 11:07:00 2017-01-01 13:00:00
# 11  2017-01-01 11:42:00 2017-01-02 11:42:00 2017-01-01 13:00:00
# 12  2017-01-01 11:46:00 2017-01-02 11:46:00 2017-01-01 22:05:00
# 13  2017-01-01 11:50:00 2017-01-02 11:50:00 2017-01-02 14:50:00
# 14  2017-01-01 12:09:00 2017-01-02 12:09:00 2017-01-02 11:35:00
# 15  2017-01-01 12:18:00 2017-01-02 12:18:00 2017-01-02 12:15:00
# 16  2017-01-01 12:19:00 2017-01-11 12:19:00 2017-02-15 02:05:00
# 17  2017-01-01 12:21:00 2017-01-06 08:00:00 2017-01-04 16:37:00
# 18  2017-01-01 12:26:00 2017-01-11 12:26:00 2017-01-01 13:35:00
# 19  2017-01-01 13:07:00 2017-01-02 13:07:00 2017-01-01 21:15:00
# 20  2017-01-01 13:11:00 2017-01-02 13:11:00 2017-01-11 01:15:00
# 21  2017-01-01 13:11:00 2017-01-02 13:11:00 2017-01-04 03:35:00
# 22  2017-01-01 13:21:00 2017-01-02 13:21:00 2017-01-02 20:20:00
# 23  2017-01-01 13:22:00 2017-01-11 13:22:00 2017-01-01 14:25:00
# 24  2017-01-01 13:35:00 2017-01-11 13:35:00 2017-01-02 06:30:00
# 0                  1      32.534722
# 1                  1       3.234722
# 2                  1       2.928472
# 3                  0       0.102083
# 4                  0       0.107639
# 5                  0       0.090972
# 6                  0       0.105556
# 7                  1      10.680556
# 8                  1       1.218056
# 9                  1       2.688194
# 10                 0       0.078472
# 11                 0       0.054167
# 12                 0       0.429861
# 13                 1       1.125000
# 14                 0       0.976389
# 15                 0       0.997917
# 16                 1      44.573611
# 17                 0       3.177778
# 18                 0       0.047917
# 19                 0       0.338889
# 20                 1       9.502778
# 21                 1       2.600000
# 22                 1       1.290972
# 23                 0       0.043750
# 24                 0       0.704861
# 25                 0       0.909722
# 26                 1      30.126389
# 27                 1       1.261806
# 28                 1      86.838194
# 29                 0       0.035417
# ..               ...            ...
# 831                0       0.260417
# 832                1       1.235417
# 833                0      15.300694
# 834                0       0.158333
# 835                0       7.297917
# 836                0       0.226389
# 837                0       9.380556
# 838                0       6.663194
# 839                1      20.256944
# 840                0       0.044444
# 841                0       1.229167
# 842                0     126.311111
# 843                0       7.986111
# 844                0       0.710417
# 845                0       0.480556
# 846                1     111.355556
# 847                1      23.087500
# 848                0       7.262500
# 849                1       6.949306
# 850                0       0.418750
# 851                1       1.304167
# 852                0       0.074306
# 853                0       5.404167
# 854                0       1.215972
# 855                0       0.193750
# 856                1       7.086806
# 857                0       0.195833
# 858                1      14.936806
# 859                0       0.126389
# 860                0       0.111806
#
# [861 rows x 5 columns]

# %%
# # bring in the weather data

# weatherdata_df = pd.read_csv("../static/data/Final_selected_weather_data.csv")

# print(weatherdata_df.shape)
# weatherdata_df.head()

# # checking the date lenght to make sure it matches with the 311 date length

# # weatherdata_df["date_len"] = weatherdata_df["date_field"].str.len() 
# # print(weatherdata_df[["date_field", "date_len"]])
# Out:
# (1180, 6)
#    Unnamed: 0  date_field  tempMax  tempAvg  tempMin  precipitation
# 0           0  2017-01-01       74     67.5       64           0.30
# 1           1  2017-01-02       74     66.9       53           0.07
# 2           2  2017-01-03       75     61.9       49           1.22
# 3           3  2017-01-04       52     46.5       42           0.00
# 4           4  2017-01-05       56     50.4       44           0.00

# %%
# # bring in the census data

# censusdata_df = pd.read_csv("../Clean Data Files/census_data.csv")
# censusdata_df.head()
# Out:
#    Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0    77002     12370.0        34.1           72306.0            34779.0
# 1    77003      9646.0        34.1           59575.0            37760.0
# 2    77004     37642.0        28.3           48592.0            31067.0
# 3    77005     28233.0        36.5          180758.0           100896.0
# 4    77006     21945.0        34.3           82878.0            68705.0
#
#    Poverty Rate  Total Households  Total Owner Occupied  % Owner Occupied
# 0      6.984640            4457.0                1213.0         27.215616
# 1     27.628032            9597.0                4731.0         49.296655
# 2     19.733277           28125.0                9997.0         35.544889
# 3      3.715510           25438.0               20433.0         80.324711
# 4      7.304625           21280.0                8945.0         42.034774

# %%
# # merge weather data into the 311 data

# data_all1_df = data311_df.merge(weatherdata_df, how="left", left_on="create_date", right_on="date_field")

# print(data_all1_df.shape)
# data_all1_df.head()

# # print(data_all[data_all["date_field"] == "2017-01-04"])

# %%
# data_final_df = data_all1_df.merge(censusdata_df, how="left", left_on="zipcode", right_on="Zipcode") 

# print(data_final_df.shape)

# data_final_df = data_final_df.drop(columns=["Zipcode","date_field"])

# print(data_final_df.columns.values)
# # data_final_df.head()

# data_final_df.describe()

# data_final_df.isna().sum()

# print(data_final_df[data_final_df["district"].isna()])
# Out:
# (861, 57)
# ['index' 'case number' 'sr location' 'county' 'district' 'neighborhood'
#  'tax id' 'trash quad' 'recycle quad' 'trash day' 'heavy trash day'
#  'recycle day' 'key map' 'management district' 'department' 'division'
#  'sr type' 'queue' 'sla' 'status' 'sr create date' 'due date'
#  'date closed' 'overdue' 'title' 'x' 'y' 'latitude' 'longitude'
#  'channel type' 'zipcode' 'openclosetime' 'openduetime' 'year'
#  'create_date' 'create_date_time' 'date_closed_time' 'due_date_time'
#  'missed_due_date' 'time_to_close' 'seconds_to_close' 'days_to_close'
#  'Unnamed: 0' 'tempMax' 'tempAvg' 'tempMin' 'precipitation' 'Population'
#  'Median Age' 'Household Income' 'Per Capita Income' 'Poverty Rate'
#  'Total Households' 'Total Owner Occupied' '% Owner Occupied']
#      index            case number                                 sr location  \
# 55     154  12091899-101002444887  5686 GRAND FLORAL, UNINCORPORATED TX 77041
# 263    735            1.01002E+11              1302 MCDUGALD, HUMBLE TX 77338
# 376   1009  12092234-101002445804    1119 RIVER GLYNN, HUNTERS CREEK TX 77063
# 639   1669  12092472-101002446612      8920 COURTNEY, UNINCORPORATED TX 77562
#
#      county district neighborhood        tax id trash quad recycle quad  \
# 55   HARRIS      NaN          NaN  1.179010e+12        NaN          NaN
# 263  HARRIS      NaN          NaN  1.012870e+12        NaN          NaN
# 376  HARRIS      NaN          NaN  7.917700e+11        NaN          NaN
# 639  HARRIS      NaN          NaN  1.005680e+12        NaN          NaN
#
#     trash day  ... tempMin precipitation Population Median Age  \
# 55        NaN  ...      64          0.30    35372.0       35.7
# 263       NaN  ...      53          0.07    40335.0       31.6
# 376       NaN  ...      49          1.22    38931.0       31.9
# 639       NaN  ...      49          1.22    10665.0       36.9
#
#     Household Income Per Capita Income Poverty Rate Total Households  \
# 55           79503.0           37841.0    10.202985          35287.0
# 263          50263.0           21826.0    14.647329          40204.0
# 376          44957.0           32805.0    22.824998          38751.0
# 639          62077.0           26589.0    13.567745          10640.0
#
#      Total Owner Occupied % Owner Occupied
# 55                27345.0        77.493128
# 263               23215.0        57.743011
# 376                9667.0        24.946453
# 639                7638.0        71.785714
#
# [4 rows x 55 columns]

# %%
# keep just the fields that will be used in analysis

# data_final_df=data_final_df[["create_date","days_to_close","missed_due_date","sr type","tempMax","tempAvg","tempMin","precipitation","Population","Median Age",
#                     "Household Income","Poverty Rate","% Owner Occupied"]]

# print(data_final_df.shape)
# print(data_final_df["create_date"].value_counts())
# data_final_df.describe()
# Out:
# (861, 13)
# 2017-01-03    511
# 2017-01-02    203
# 2017-01-04     79
# 2017-01-01     68
# Name: create_date, dtype: int64
#        days_to_close  missed_due_date     tempMax     tempAvg     tempMin  \
# count     861.000000       861.000000  861.000000  861.000000  861.000000
# mean       14.643768         0.319396   72.574913   62.108130   50.485482
# std        37.308855         0.466514    6.559071    5.488447    4.884607
# min         0.000694         0.000000   52.000000   46.500000   42.000000
# 25%         0.536806         0.000000   74.000000   61.900000   49.000000
# 50%         1.378472         0.000000   75.000000   61.900000   49.000000
# 75%         7.795833         1.000000   75.000000   66.900000   53.000000
# max       385.361111         1.000000   75.000000   67.500000   64.000000
#
#        precipitation     Population  Median Age  Household Income  \
# count     861.000000     861.000000  861.000000        861.000000
# mean        0.764262   33776.849013   33.723926      56535.933798
# std         0.554872   13733.980413    3.040652      29485.480188
# min         0.000000     915.000000   24.400000      26644.000000
# 25%         0.070000   22799.000000   31.900000      34842.000000
# 50%         1.220000   32556.000000   33.800000      45953.000000
# 75%         1.220000   39915.000000   34.900000      66775.000000
# max         1.220000  104582.000000   45.100000     250001.000000
#
#        Poverty Rate  % Owner Occupied
# count    861.000000        861.000000
# mean      20.704777         51.632477
# std        9.764555         13.121672
# min        3.169474          4.864466
# 25%       11.186171         44.026696
# 50%       22.410745         50.140064
# 75%       28.398222         59.136876
# max       39.548570         90.290089

# %% [markdown]
# ### Read in the final version of the data that has the weather and census data merged in already.

# %%
data_final_df = pd.read_csv("../static/dataignore/modeldata.csv")

# %%
print(data_final_df.columns.values)
data_final_df.head()
# Out:
# ['case number' 'sr location' 'county' 'district' 'neighborhood' 'tax id'
#  'trash quad' 'recycle quad' 'trash day' 'heavy trash day' 'recycle day'
#  'key map' 'management district' 'department' 'division' 'sr type' 'queue'
#  'sla' 'status' 'sr create date' 'due date' 'date closed' 'overdue'
#  'title' 'latitude' 'longitude' 'channel type' 'date' 'year' 'month'
#  'zipcode' 'daystoclose' 'daysdue' 'missedduedate' 'date_field' 'tempMax'
#  'tempAvg' 'tempMin' 'precipitation' 'Population' 'Median Age'
#  'Household Income' 'Per Capita Income' 'Poverty Rate' 'Total Households'
#  'Total Owner Occupied' '% Owner Occupied']
#              case number                                       sr location  \
# 0           101002444726  Intersection 3900 S GESSNER RD&10000 WESTPARK DR
# 1  12091836-101002444730                       3303 SAGE, HOUSTON TX 77056
# 2           101002444733        Intersection 1400 CAROLINE ST&1300 CLAY ST
# 3  12091839-101002444736                   7701 APPLETON, HOUSTON TX 77022
# 4  12091840-101002444737                   7701 APPLETON, HOUSTON TX 77022
#
#           county district         neighborhood         tax id trash quad  \
# 0  Harris County        F             MID WEST            NaN        NaN
# 1         HARRIS        G       GREATER UPTOWN  0451400060009        NaN
# 2  Harris County        I             DOWNTOWN            NaN        NaN
# 3         HARRIS        H  NORTHSIDE/NORTHLINE  0710210010015         NE
# 4         HARRIS        H  NORTHSIDE/NORTHLINE  0420050000055         NE
#
#   recycle quad trash day heavy trash day  ... tempMin precipitation  \
# 0          NaN       NaN             NaN  ...    64.0           0.3
# 1          NaN       NaN             NaN  ...    64.0           0.3
# 2          NaN       NaN             NaN  ...    64.0           0.3
# 3           NW    MONDAY      3rd Monday  ...    64.0           0.3
# 4           NW    MONDAY      3rd Monday  ...    64.0           0.3
#
#   Population Median Age Household Income Per Capita Income Poverty Rate  \
# 0    38931.0       31.9          44957.0           32805.0    22.824998
# 1    21732.0       39.1         107003.0           89180.0     5.268728
# 2      915.0       44.6         250001.0          196722.0     6.666667
# 3    27364.0       34.1          30164.0           14924.0    29.399942
# 4    27364.0       34.1          30164.0           14924.0    29.399942
#
#    Total Households Total Owner Occupied % Owner Occupied
# 0           38751.0               9667.0        24.946453
# 1           21641.0              10643.0        49.179798
# 2             915.0                 78.0         8.524590
# 3           27186.0              13143.0        48.344736
# 4           27186.0              13143.0        48.344736
#
# [5 rows x 47 columns]

# %%
################################################################
# create a date value formatted the same as the weather data

splitdate = data_final_df["sr create date"].str.split(" ", n=1, expand=True)

data_final_df["create_date"] = splitdate[0]
data_final_df["create_date"] = pd.to_datetime(data_final_df["create_date"])
data_final_df["create_date"] = data_final_df['create_date'].dt.strftime('%Y-%m-%d')


# I set these as date formats using the to_datetime

data_final_df["create_date_time"] = pd.to_datetime(data_final_df["sr create date"])
data_final_df["date_closed_time"] = pd.to_datetime(data_final_df["date closed"])
data_final_df["due_date_time"] = pd.to_datetime(data_final_df["due date"])


# here  I define weather is was closed by the due date (0) or not (1)
data_final_df["missed_due_date"] = np.where(data_final_df["due_date_time"] > data_final_df["date_closed_time"], 0, 1)

# calculate the difference between the closed date at the create date
data_final_df["time_to_close"] = data_final_df["date_closed_time"] - data_final_df["create_date_time"]

# apply formatting so that is is in seconds. then calculate the number of days.
data_final_df["seconds_to_close"] = data_final_df["time_to_close"].astype('timedelta64[s]')
data_final_df["days_to_close"] = data_final_df["seconds_to_close"]/60/60/24
 
# data311_df[["create_date_time", "date_closed_time", "time_to_close","seconds_to_close", "days_to_close"]]


data_final_df[["create_date_time","due_date_time", "date_closed_time", "missed_due_date", "days_to_close"]]

print(data_final_df[data_final_df["Poverty Rate"].isna()])
# Out:
#                   case number  \
# 280     12092050-101002445261
# 291     12092058-101002445277
# 311              101002445313
# 312              101002445313
# 313              101002445313
# 321      1330044-101002445332
# 322      1330044-101002445332
# 323      1330044-101002445332
# 395              101002445458
# 396              101002445458
# 397              101002445458
# 637              101002445997
# 1193             101002447192
# 1886    12093008-101002448713
# 2280             101002449611
# 2290             101002449637
# 3711     1331666-101002452051
# 3762             101002452146
# 3971    12094478-101002452508
# 3979    12094487-101002452530
# 4004             101002452600
# 4019    12094529-101002452628
# 5663             101002455915
# 6091     1332946-101002456836
# 6367             101002457445
# 6377             101002457470
# 6382             101002457494
# 6399             101002457535
# 6490     1333179-101002457764
# 6680    12096240-101002458134
# ...                       ...
# 668371   1731164-101003908802
# 668388   1731174-101003908849
# 668513   1731407-101003909119
# 668517  12424378-101003909128
# 668545           101003909208
# 669065  12424461-101003920320
# 669160           101003920512
# 670917           101003924346
# 671786           101003926137
# 672008  12424845-101003926692
# 672463  12424901-101003927746
# 672856           101003928575
# 672953           101003928743
# 673079  12424957-101003928938
# 673140           101003929037
# 673269           101003929289
# 673349           101003929424
# 673439  12425023-101003929613
# 673682  12425051-101003930169
# 673759   1734470-101003930294
# 673853           101003930474
# 673269           Intersection 700 BAGBY ST&400 CAPITOL ST  Harris County
# 673349        Intersection 1100 COMMERCE ST&100 FANNIN ST  Harris County
# 673439  Intersection 1100 ROTHWELL ST&1100 N SAN JACIN...  Harris County
# 673682  Intersection 1100 ROTHWELL ST&1100 N SAN JACIN...  Harris County
# 673759  Intersection 1000 HOUSTON AVE&1500 WASHINGTON AVE  Harris County
# 673853        Intersection 1100 COMMERCE ST&100 FANNIN ST  Harris County
# 674373            Intersection 500 JAMES ST&2000 KEENE ST  Harris County
# 674648          Intersection 400 N MAIN ST&1100 NAYLOR ST  Harris County
# 674652          Intersection 800 HOUSTON AVE&1500 KANE ST  Harris County
# 674653          Intersection 800 HOUSTON AVE&1500 KANE ST  Harris County
# 674926       Intersection 700 HOUSTON AVE&1500 LUBBOCK ST  Harris County
# 675038       Intersection 700 HOUSTON AVE&1500 LUBBOCK ST  Harris County
# 675608            Intersection 0 ALLEN PKWY&800 CROSBY ST  Harris County
# 675948            Intersection 0 ALLEN PKWY&800 CROSBY ST  Harris County
# 676447  Intersection 2 CAPITOL ST&1400 N MEMORIAL WAY&...  Harris County
#
#        district                              neighborhood tax id trash quad  \
# 280           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 291           I                                  DOWNTOWN    NaN        NaN
# 311           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 312           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 313           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 321           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 322           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 323           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 395           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 396           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 397           H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 637           I                                  DOWNTOWN    NaN        NaN
# 1193          H                            NEAR NORTHSIDE    NaN         NE
# 1886          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 2280          I                                  DOWNTOWN    NaN        NaN
# 2290          I                                  DOWNTOWN    NaN        NaN
# 3711          C                               FOURTH WARD    NaN        NaN
# 3762          I                                  DOWNTOWN    NaN        NaN
# 3971          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 3979          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 4004          I                                  DOWNTOWN    NaN        NaN
# 4019          I                                  DOWNTOWN    NaN        NaN
# 5663          I                                  DOWNTOWN    NaN        NaN
# 6091          I                                  DOWNTOWN    NaN        NaN
# 6367          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 6377          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 6382          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 6399          H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 6490          I                                  DOWNTOWN    NaN        NaN
# 6680          H                            NEAR NORTHSIDE    NaN        NaN
# ...         ...                                       ...    ...        ...
# 668371        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 668388        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 668513        C                               FOURTH WARD    NaN        NaN
# 668517        I                                  DOWNTOWN    NaN        NaN
# 668545        I                                  DOWNTOWN    NaN        NaN
# 669065        C                               FOURTH WARD    NaN        NaN
# 669160        C                               FOURTH WARD    NaN        NaN
# 670917        C                               FOURTH WARD    NaN        NaN
# 671786        H                            NEAR NORTHSIDE    NaN         NE
# 672008        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 672463        I                                  DOWNTOWN    NaN        NaN
# 672856        I                                  DOWNTOWN    NaN        NaN
# 672953        I                                  DOWNTOWN    NaN        NaN
# 673079        I                                  DOWNTOWN    NaN        NaN
# 673140        I                                  DOWNTOWN    NaN        NaN
# 673269        I                                  DOWNTOWN    NaN        NaN
# 673349        H                                  DOWNTOWN    NaN        NaN
# 673439        H                                  DOWNTOWN    NaN         NE
# 673682        H                                  DOWNTOWN    NaN         NE
# 673759        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 673853        H                                  DOWNTOWN    NaN        NaN
# 674373        H                            NEAR NORTHSIDE    NaN         NE
# 674648        H                                  DOWNTOWN    NaN        NaN
# 674652        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 674653        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
# 674926        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 675038        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN         NW
# 675608        C                               FOURTH WARD    NaN        NaN
# 675948        C                               FOURTH WARD    NaN        NaN
# 676447        H  WASHINGTON AVENUE COALITION / MEMORIAL P    NaN        NaN
#
#        recycle quad trash day heavy trash day  ... Total Owner Occupied  \
# 280              NW    MONDAY   1st Wednesday  ...                  0.0
# 291             NaN       NaN             NaN  ...                  0.0
# 311              NW    MONDAY   1st Wednesday  ...                  0.0
# 312              NW    MONDAY   1st Wednesday  ...                  0.0
# 313              NW    MONDAY   1st Wednesday  ...                  0.0
# 321              NW    MONDAY   1st Wednesday  ...                  0.0
# 322              NW    MONDAY   1st Wednesday  ...                  0.0
# 323              NW    MONDAY   1st Wednesday  ...                  0.0
# 395              NW    MONDAY   1st Wednesday  ...                  0.0
# 396              NW    MONDAY   1st Wednesday  ...                  0.0
# 397              NW    MONDAY   1st Wednesday  ...                  0.0
# 637             NaN       NaN             NaN  ...                  0.0
# 1193            NaN    FRIDAY             NaN  ...                  0.0
# 1886             NW    MONDAY   1st Wednesday  ...                  0.0
# 2280            NaN       NaN             NaN  ...                  0.0
# 2290            NaN       NaN             NaN  ...                  0.0
# 3711            NaN       NaN             NaN  ...                  0.0
# 3762            NaN       NaN             NaN  ...                  0.0
# 3971            NaN    MONDAY   1st Wednesday  ...                  0.0
# 3979             NE    MONDAY   1st Wednesday  ...                  0.0
# 4004            NaN       NaN             NaN  ...                  0.0
# 4019            NaN       NaN             NaN  ...                  0.0
# 5663            NaN       NaN             NaN  ...                  0.0
# 6091            NaN       NaN             NaN  ...                  0.0
# 6367             NE    MONDAY   1st Wednesday  ...                  0.0
# 6377             NE    MONDAY   1st Wednesday  ...                  0.0
# 6382            NaN       NaN             NaN  ...                  0.0
# 6399            NaN       NaN             NaN  ...                  0.0
# 6490            NaN       NaN             NaN  ...                  0.0
# 6680            NaN       NaN             NaN  ...                  0.0
# ...             ...       ...             ...  ...                  ...
# 668371          NaN       NaN             NaN  ...                  0.0
# 668388          NaN       NaN             NaN  ...                  0.0
# 668513          NaN       NaN             NaN  ...                  0.0
# 668517          NaN       NaN             NaN  ...                  0.0
# 668545          NaN       NaN             NaN  ...                  0.0
# 669065          NaN       NaN             NaN  ...                  0.0
# 669160          NaN       NaN             NaN  ...                  0.0
# 670917          NaN       NaN             NaN  ...                  0.0
# 671786          NaN    FRIDAY             NaN  ...                  0.0
# 672008           NW    MONDAY   1st Wednesday  ...                  0.0
# 672463          NaN       NaN             NaN  ...                  0.0
# 672856          NaN       NaN             NaN  ...                  0.0
# 672953          NaN       NaN             NaN  ...                  0.0
# 673079          NaN       NaN             NaN  ...                  0.0
# 673140          NaN       NaN             NaN  ...                  0.0
# 673269          NaN       NaN             NaN  ...                  0.0
# 673349          NaN       NaN             NaN  ...                  0.0
# 673439          NaN    FRIDAY             NaN  ...                  0.0
# 673682          NaN    FRIDAY             NaN  ...                  0.0
# 673759           NW       NaN             NaN  ...                  0.0
# 673853 2020-03-24 16:19:08               0   0 days 02:53:50          10430.0
# 674373 2020-04-13 14:13:18               0   0 days 23:11:01          83461.0
# 674648 2020-03-26 07:55:00               0   0 days 00:33:55           2035.0
# 674652 2020-03-26 08:11:06               0   0 days 00:00:20             20.0
# 674653 2020-04-14 08:11:35               0   0 days 23:47:44          85664.0
# 674926 2020-04-14 13:27:02               0   0 days 19:27:17          70037.0
# 675038 2020-04-14 16:09:15               0   0 days 16:45:02          60302.0
# 675608 2020-03-27 16:19:57               0   0 days 01:41:40           6100.0
# 675948 2020-04-16 12:03:00               1 279 days 11:56:13       24148573.0
# 676447 2020-04-07 13:06:05               1 278 days 10:53:55       24058435.0
#
#        days_to_close
# 280         3.046632
# 291         0.675451
# 311         0.012708
# 312         0.012708
# 313         0.012708
# 321         1.864780
# 322         1.864780
# 323         1.864780
# 395         0.005532
# 396         0.005532
# 397         0.005532
# 637         0.073808
# 1193        0.114282
# 1886       11.922269
# 2280        0.113646
# 2290        0.317905
# 3711        4.837512
# 3762        0.158264
# 3971        1.124988
# 3979        0.617928
# 4004        0.267685
# 4019        0.756759
# 5663        0.070856
# 6091        0.820081
# 6367        0.019167
# 6377        0.040104
# 6382        0.101181
# 6399        0.002940
# 6490       12.038576
# 6680        5.889109
# ...              ...
# 668371      0.020579
# 668388      5.306169
# 668513      3.822639
# 668517      0.099502
# 668545      0.016019
# 669065      4.003437
# 669160      0.350683
# 670917      0.097824
# 671786      0.100324
# 672008      1.059699
# 672463      2.853148
# 672856      0.062604
# 672953      0.121863
# 673079      1.797396
# 673140      0.107280
# 673269      0.085810
# 673349      0.664873
# 673439      0.043981
# 673682      0.779884
# 673759      3.764352
# 673853      0.120718
# 674373      0.965984
# 674648      0.023553
# 674652      0.000231
# 674653      0.991481
# 674926      0.810613
# 675038      0.697940
# 675608      0.070602
# 675948    279.497373
# 676447    278.454109
#
# [1233 rows x 55 columns]

# %%
# keep just the fields that will be used in analysis

data_final_df=data_final_df[["create_date","days_to_close","missed_due_date","sr type","tempMax","precipitation","Population","Median Age",
                    "Household Income","Poverty Rate","% Owner Occupied"]]


data_final_df["sr type"].value_counts()

data_final_df=data_final_df[data_final_df["create_date"] >= "2019-01-01"  ]

# There were some entries where we were not able to get the zipcode, thus we weren't able to map in the 
# weather data and census data, so dropping these in able to do modeling

data_final_df = data_final_df.dropna()
data_final_df.isna().sum()
# Out:
# create_date         0
# days_to_close       0
# missed_due_date     0
# sr type             0
# tempMax             0
# precipitation       0
# Population          0
# Median Age          0
# Household Income    0
# Poverty Rate        0
# % Owner Occupied    0
# dtype: int64

# %%
data_final_df.describe()

# data_final_df[data_final_df["days_to_close"]>500].shape

data_final_df.shape
# Out:
# (227068, 11)

# %%
data_final_df["days_to_close"].hist()

# %%
data_final_df.plot.scatter(x="precipitation", y="days_to_close")

# %%
# need to create dummy variable for the "sr type" column, which is categorical

data_dummies_df=pd.get_dummies(data_final_df["sr type"])



# add dummy variables in to dataframe with other variables

data_regress_df=pd.concat([data_final_df, data_dummies_df], axis=1)   

# create y variable for the regression analysis

y=data_final_df["days_to_close"].values.reshape(-1,1)


# create x variables (easier to just drop columns that aren't needed)

X_var=data_regress_df.drop(columns=["sr type","days_to_close", "missed_due_date","create_date"])
X_var.isna().sum()
 
print(X_var.shape)
print(X_var.columns.values)
X_var.head()  


# Below I am looking at droppiing different combinations of the x variables to see how it affects the model.

# X_var=X_var[["tempMax","precipitation", "Household Income","Poverty Rate","% Owner Occupied"]]


# X_var=X_var[['Drainage' ,'Missed Garbage Pickup', 'Missed Heavy Trash Pickup',
#  'Missed Recycling Pickup', 'Nuisance On Property', 'SWM Escalation',
#  'Sewer Wastewater', 'Storm Debris Collection', 'Street Condition',
#  'Street Hazard', 'Traffic Signal Maintenance', 'Traffic Signs', 'Water Leak',
#  'Water Service']]

# X_var=X_var[['tempMax']]
# Out:
# (227068, 22)
# ['tempMax' 'precipitation' 'Population' 'Median Age' 'Household Income'
#  'Poverty Rate' '% Owner Occupied' 'Container Problem' 'Drainage'
#  'Missed Garbage Pickup' 'Missed Heavy Trash Pickup'
#  'Missed Recycling Pickup' 'Nuisance On Property' 'SWM Escalation'
#  'Sewer Wastewater' 'Storm Debris Collection' 'Street Condition'
#  'Street Hazard' 'Traffic Signal Maintenance' 'Traffic Signs' 'Water Leak'
#  'Water Service']
#         tempMax  precipitation  Population  Median Age  Household Income  \
# 447875     65.0           0.03     62162.0        32.7           41041.0
# 447876     65.0           0.03     57757.0        34.8           66587.0
# 447877     65.0           0.03     37751.0        35.1           49383.0
# 447878     65.0           0.03     62162.0        32.7           41041.0
# 447879     65.0           0.03     37751.0        35.1           49383.0
#
#         Poverty Rate  % Owner Occupied  Container Problem  Drainage  \
# 447875     24.551977         48.067306                  0         0
# 447876     10.369306         40.120674                  0         0
# 447877     24.232471         53.967659                  0         0
# 447878     24.551977         48.067306                  0         0
# 447879     24.232471         53.967659                  0         0
#
#         Missed Garbage Pickup  ...  Nuisance On Property  SWM Escalation  \
# 447875                      0  ...                     0               0
# 447876                      1  ...                     0               0
# 447877                      0  ...                     0               0
# 447878                      0  ...                     0               0
# 447879                      0  ...                     0               0
#
#         Sewer Wastewater  Storm Debris Collection  Street Condition  \
# 447875                 0                        0                 0
# 447876                 0                        0                 0
# 447877                 0                        0                 0
# 447878                 0                        0                 0
# 447879                 0                        0                 0
#
#         Street Hazard  Traffic Signal Maintenance  Traffic Signs  Water Leak  \
# 447875              0                           0              0           1
# 447876              0                           0              0           0
# 447877              0                           0              0           0
# 447878              0                           0              0           0
# 447879              0                           0              0           1
#
#         Water Service
# 447875              0
# 447876              0
# 447877              0
# 447878              0
# 447879              0
#
# [5 rows x 22 columns]

# %%
data_regress_df.plot.scatter(x="Nuisance On Property", y="days_to_close")

# %% [markdown]
# ### Build regression model to predict number of days until issue was closed

# %%
from sklearn.model_selection import train_test_split

# random_state is just an arbitrarily selected number that we use to maintain the same random split each time we run this cell.
X_train, X_test, y_train, y_test = train_test_split(X_var, y, random_state=5)

# %%
# scale the data

from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
from sklearn.linear_model import LinearRegression

# Create a linear model
model_regress = LinearRegression()

model_regress.fit(X_train_scaled, y_train_scaled)

print(f"Training Score:  {model_regress.score(X_train_scaled, y_train_scaled)}")
print(f"Test Score: {model_regress.score(X_test_scaled, y_test_scaled)}")
# Out:
# Training Score:  0.0036017563310234424
# Test Score: 0.0030182138380508983

# %%
print('Weight coefficients: ', model_regress.coef_)
print('y-axis intercept: ', model_regress.intercept_)
# Out:
# Weight coefficients:  [[0.06001463]]
# y-axis intercept:  [-4.17996471e-17]

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to predict a value
predicted = model_regress.predict(X_train_scaled)

# Score the prediction with mse and r2
mse = mean_squared_error(y_train_scaled, predicted)
r2 = r2_score(y_train_scaled, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 0.9963982436689762
# R-squared (R2 ): 0.0036017563310234424

# %%
model_regress.score(X_test_scaled, y_test_scaled)
# Out:
# 0.0030182138380508983

# %%
# look at residuals

res = predicted - y_train_scaled

res
# Out:
# array([[ 0.25094338],
#        [ 0.32547472],
#        [-0.61976022],
#        ...,
#        [ 0.19552282],
#        [ 0.21457466],
#        [-0.30624908]])

# %%
plt.hist(y_train_scaled)
# Out:
# (array([1.58048e+05, 4.08700e+03, 9.88000e+02, 1.31800e+03, 7.73000e+02,
#         1.67000e+03, 2.36500e+03, 9.81000e+02, 6.30000e+01, 8.00000e+00]),
#  array([-0.33670563,  0.51329823,  1.36330209,  2.21330594,  3.0633098 ,
#          3.91331366,  4.76331751,  5.61332137,  6.46332523,  7.31332909,
#          8.16333294]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(predicted, res)

# %%
# output model to pickle

import pickle

with open('../static/models/regression_model.pkl','wb') as f:
    pickle.dump(model_regress, f)

# %% [markdown]
# ### Build Logistic Regression Model to predict if issue was not closed by due date

# %%
# I need to define y as the classfication variable.  The X_var can stay the same

y_class = data_final_df["missed_due_date"]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(C=59, penalty='l1')
classifier
# Out:
# LogisticRegression(C=59, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l1',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# define training and test sets

from sklearn.model_selection import train_test_split


X_train, X_test, y_class_train, y_class_test = train_test_split(X_var, y_class, random_state=33)

# %%
# define standard scaler

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)

# %%
# scale the x data (y is just 0 or 1, so not scaling)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# fit the model

classifier.fit(X_train_scaled, y_class_train)
# Out:
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=59, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l1',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# look at the scores

print(f"Training Data Score: {classifier.score(X_train_scaled, y_class_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_class_test)}")
# Out:
# Training Data Score: 0.7079465182236159
# Testing Data Score: 0.7073828104356404

# %%
predictions = classifier.predict(X_test_scaled)
probs = classifier.predict_proba(X_test_scaled)


pd.DataFrame({
    "Prediction": predictions, 
    "Actual": y_class_test, 
    "On Time": [p[0] for p in probs], 
    "Overdue": [p[1] for p in probs]})
# Out:
#         Prediction  Actual   On Time   Overdue
# 548442           0       0  0.551515  0.448485
# 627671           0       0  0.615429  0.384571
# 540668           0       0  0.642220  0.357780
# 589013           0       1  0.638473  0.361527
# 516414           0       0  0.590449  0.409551
# 598008           0       0  0.648697  0.351303
# 478049           1       1  0.413654  0.586346
# 573524           1       1  0.475498  0.524502
# 539869           0       0  0.891414  0.108586
# 494622           0       0  0.936862  0.063138
# 635422           1       1  0.228876  0.771124
# 555292           1       0  0.393428  0.606572
# 571203           1       1  0.234832  0.765168
# 533532           0       0  0.722559  0.277441
# 454778           0       0  0.910045  0.089955
# 449293           0       1  0.668798  0.331202
# 643573           0       0  0.892192  0.107808
# 524111           1       1  0.486660  0.513340
# 507441           0       0  0.643690  0.356310
# 644508           0       0  0.709174  0.290826
# 582646           0       0  0.649716  0.350284
# 460266           1       1  0.495856  0.504144
# 634997           0       0  0.883321  0.116679
# 509811           0       1  0.674378  0.325622
# 550000           0       0  0.870248  0.129752
# 483594           1       0  0.238526  0.761474
# 528316           0       0  0.539110  0.460890
# 510208           0       0  0.624550  0.375450
# 448700           1       0  0.446633  0.553367
# 473808           0       0  0.860235  0.139765
# ...            ...     ...       ...       ...
# 517526           0       0  0.653755  0.346245
# 491135           0       0  0.871938  0.128062
# 601828           1       1  0.457088  0.542912
# 522400           1       1  0.449406  0.550594
# 487834           0       1  0.510132  0.489868
# 518578           1       1  0.430095  0.569905
# 633858           0       0  0.501220  0.498780
# 657376           0       0  0.659196  0.340804
# 531361           1       0  0.447651  0.552349
# 663411           0       0  0.651198  0.348802
# 473257           1       0  0.465094  0.534906
# 522063           1       1  0.472933  0.527067
# 656535           0       1  0.523092  0.476908
# 501004           1       0  0.269878  0.730122
# 577896           0       0  0.886532  0.113468
# 525450           0       0  0.876471  0.123529
# 663906           0       0  0.566486  0.433514
# 510890           1       0  0.233450  0.766550
# 639996           0       0  0.863705  0.136295
# 470638           0       1  0.517125  0.482875
# 654334           0       1  0.624865  0.375135
# 626981           1       1  0.408867  0.591133
# 482988           0       1  0.596534  0.403466
# 638513           0       0  0.864781  0.135219
# 452494           1       0  0.440315  0.559685
# 634609           0       0  0.507809  0.492191
# 588139           0       0  0.606137  0.393863
# 512385           0       1  0.653095  0.346905
# 610991           0       0  0.870222  0.129778
# 527861           1       1  0.440033  0.559967
#
# [56767 rows x 4 columns]

# %% [markdown]
# #### Do a grid search to try and find a better model.  Note that this grid search ended up suggesting the default model.

# %%
logistic = LogisticRegression()

# %%
# Create regularization penalty space
penalty = ['l1', 'l2']

# Create regularization hyperparameter space
C = np.logspace(0, 4, 10)

# Create hyperparameter options
hyperparameters = dict(C=C, penalty=penalty)

# %%
# Create grid search using 5-fold cross validation
clf = GridSearchCV(logistic, hyperparameters, cv=5, verbose=0)

# %%
# Fit grid search
best_model = clf.fit(X_train_scaled, y_class_train)
# Out:
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\jeickholt\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# View best hyperparameters
print('Best Penalty:', best_model.best_estimator_.get_params()['penalty'])
print('Best C:', best_model.best_estimator_.get_params()['C'])
# Out:
# Best Penalty: l1
# Best C: 59.94842503189409

# %% [markdown]
# #### Ends up the that grid search showed the default values were best

# %%
# output model to pickle

import pickle

with open('../static/models/logistic_model.pkl','wb') as f:
    pickle.dump(classifier, f)

# %% [markdown]
# ### Develop KNN model to predict if issue was not closed by due date

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_class_train)
print('k=5 Test Acc: %.3f' % knn.score(X_train, y_class_train))
knn
# Out:
# k=5 Test Acc: 0.655
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# output model using pickle

import pickle

with open('../static/models/knn_model.pkl','wb') as f:
    pickle.dump(knn, f)
