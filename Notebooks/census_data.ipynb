# %% [markdown]
# # Explore the Census Wrapper and API
#
# ### Requirements
# * install the `census` module before getting started. To do this, run the following command from the command line:
#     * **`pip install census`**
#
# ### Documentation
# * [Python wrapper for census API](https://github.com/datamade/census)
# * [List of available fields and labels](https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b)
# * [Census API Docs](https://www.census.gov/data/developers/data-sets.html)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
from census import Census #<-- Python wrapper for census API
import requests

# Census API Key
from config import api_key

# provide the api key and the year to establish a session
c = Census(api_key, year=2017)

# Set an option to allow up to 300 characters to print in each column
pd.set_option('max_colwidth', 300)

# %% [markdown]
# ### Gather all of the available tables for the 2013 ACS5 data
#
# There are a number of convenient methods that the wrapper provides, but the standard function requires a tuple of field IDs that you're interested in, and a geographic reference stored in a dictionary as seen below. In this code, we're saying we want data for these 6 fields for ALL zip codes
#
# **NOTE:** We're using the `acs5` function set to pull our data from the 5-year American Consumer Survey.

# %%
# query for all tables
tables = c.acs5.tables()

# The tables variable contains a list of dicts, so we can convert directly to a dataframe
table_df = pd.DataFrame(tables)
print(f"Number of available tables: {len(table_df)}")
table_df.head(15)
# Out:
# Number of available tables: 1127
#                                                                                                                                                           description  \
# 0   POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME
# 1                                                                                                                                  SEX BY AGE BY COGNITIVE DIFFICULTY
# 2                                                        POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY WORK EXPERIENCE OF HOUSEHOLDER AND SPOUSE
# 3                                                                                                                                 SEX BY AGE BY AMBULATORY DIFFICULTY
# 4                                                                                        POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER
# 5                                                                                                                                  SEX BY AGE BY SELF-CARE DIFFICULTY
# 6                                                         POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER
# 7                                                                                                                         SEX BY AGE BY INDEPENDENT LIVING DIFFICULTY
# 8                                                                                  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO
# 9                                                                          PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE)
# 10                                                                               AGGREGATE INCOME DEFICIT (DOLLARS) IN THE PAST 12 MONTHS FOR FAMILIES BY FAMILY TYPE
# 11                                                    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF RELATED CHILDREN UNDER 18 YEARS
# 12                                                                                                                                    SEX BY AGE BY DISABILITY STATUS
# 13                                                                  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF PERSONS IN FAMILY
# 14                                                                                                                                   SEX BY AGE BY HEARING DIFFICULTY
#
#         name                                                       variables
# 0     B17015    https://api.census.gov/data/2017/acs/acs5/groups/B17015.json
# 1     B18104    https://api.census.gov/data/2017/acs/acs5/groups/B18104.json
# 2     B17016    https://api.census.gov/data/2017/acs/acs5/groups/B17016.json
# 3     B18105    https://api.census.gov/data/2017/acs/acs5/groups/B18105.json
# 4     B17017    https://api.census.gov/data/2017/acs/acs5/groups/B17017.json
# 5     B18106    https://api.census.gov/data/2017/acs/acs5/groups/B18106.json
# 6     B17018    https://api.census.gov/data/2017/acs/acs5/groups/B17018.json
# 7     B18107    https://api.census.gov/data/2017/acs/acs5/groups/B18107.json
# 8   B07001PR  https://api.census.gov/data/2017/acs/acs5/groups/B07001PR.json
# 9    B19301A   https://api.census.gov/data/2017/acs/acs5/groups/B19301A.json
# 10    B17011    https://api.census.gov/data/2017/acs/acs5/groups/B17011.json
# 11    B17012    https://api.census.gov/data/2017/acs/acs5/groups/B17012.json
# 12    B18101    https://api.census.gov/data/2017/acs/acs5/groups/B18101.json
# 13    B17013    https://api.census.gov/data/2017/acs/acs5/groups/B17013.json
# 14    B18102    https://api.census.gov/data/2017/acs/acs5/groups/B18102.json

# %% [markdown]
# ### Execute a string search against the *description* column to filter to an area of interest

# %%
table_df[table_df['description'].str.contains("MEDIAN VALUE")]
# Out:
#                                           description    name  \
# 65          MORTGAGE STATUS BY MEDIAN VALUE (DOLLARS)  B25097
# 133           MEDIAN VALUE (DOLLARS) FOR MOBILE HOMES  B25083
# 303                            MEDIAN VALUE (DOLLARS)  B25077
# 934              MEDIAN VALUE BY YEAR STRUCTURE BUILT  B25107
# 936  MEDIAN VALUE BY YEAR HOUSEHOLDER MOVED INTO UNIT  B25109
#
#                                                         variables
# 65   https://api.census.gov/data/2017/acs/acs5/groups/B25097.json
# 133  https://api.census.gov/data/2017/acs/acs5/groups/B25083.json
# 303  https://api.census.gov/data/2017/acs/acs5/groups/B25077.json
# 934  https://api.census.gov/data/2017/acs/acs5/groups/B25107.json
# 936  https://api.census.gov/data/2017/acs/acs5/groups/B25109.json

# %% [markdown]
# ### Use the provided URL for your table of interest to retrieve all available variables
#
# Note: I couldn't find a wrapper function for this, so we're using requests to make the API call

# %%
# Determine which table you're interested in
table_id = 'B19013'

# Capture the variables URL from the table_df
url = table_df.loc[table_df['name']==table_id, 'variables'].values[0]

# Make the API call
response = requests.get(url).json()

# convert the response to a DataFrame
variables = pd.DataFrame(response['variables']).transpose()

print(f"Number of available variables: {len(variables)}")
variables
# Out:
# Number of available variables: 4
#                                                                                          concept  \
# B19013_001MA                                                                                 NaN
# B19013_001EA                                                                                 NaN
# B19013_001E   MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)
# B19013_001M   MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)
#
#                group  \
# B19013_001MA  B19013
# B19013_001EA  B19013
# B19013_001E   B19013
# B19013_001M   B19013
#
#                                                                                                                           label  \
# B19013_001MA  Annotation of Margin of Error!!Median household income in the past 12 months (in 2017 inflation-adjusted dollars)
# B19013_001EA         Annotation of Estimate!!Median household income in the past 12 months (in 2017 inflation-adjusted dollars)
# B19013_001E                        Estimate!!Median household income in the past 12 months (in 2017 inflation-adjusted dollars)
# B19013_001M                 Margin of Error!!Median household income in the past 12 months (in 2017 inflation-adjusted dollars)
#
#              limit predicateOnly predicateType
# B19013_001MA     0          True        string
# B19013_001EA     0          True        string
# B19013_001E      0          True           int
# B19013_001M      0          True           int

# %% [markdown]
# ### Filter to only fields that will contain an integer
#
# Many of the available variables for a table are annotation (notes) fields that are typically null. Luckily the API lets us know what data type each variable is. We can use this to filter to only the ones that will contain an integer.

# %%
variables[variables['predicateType']=='int']
# variables
# Out:
#                                                         concept   group  \
# B17001_050M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_050E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_051E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_051M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_052E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_052M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_053E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_053M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_054E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_054M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_055E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_055M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_056E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_056M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_057E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_057M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_058E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_058M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_059M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_059E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_040E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_040M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_041E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_041M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_042E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_042M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_043E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_043M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_044E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_044M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# ...                                                         ...     ...
# B17001_012E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_012M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_013E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_013M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_014E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_014M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_015M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_015E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_016M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_016E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_017M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_017E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_006M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_006E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_007M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_007E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_008M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_008E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_009M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_009E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_001E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_001M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_002E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_002M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_003E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_003M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_004M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_004E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_005M  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
# B17001_005E  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE  B17001
#
#                                                                                                                  label  \
# B17001_050M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!12 to 14 years
# B17001_050E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!12 to 14 years
# B17001_051E                  Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!15 years
# B17001_051M           Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!15 years
# B17001_052E           Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!16 and 17 years
# B17001_052M    Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!16 and 17 years
# B17001_053E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!18 to 24 years
# B17001_053M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!18 to 24 years
# B17001_054E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!25 to 34 years
# B17001_054M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!25 to 34 years
# B17001_055E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!35 to 44 years
# B17001_055M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!35 to 44 years
# B17001_056E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!45 to 54 years
# B17001_056M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!45 to 54 years
# B17001_057E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!55 to 64 years
# B17001_057M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!55 to 64 years
# B17001_058E            Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!65 to 74 years
# B17001_058M     Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!65 to 74 years
# B17001_059M  Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Female!!75 years and over
# B17001_059E         Estimate!!Total!!Income in the past 12 months at or above poverty level!!Female!!75 years and over
# B17001_040E              Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!25 to 34 years
# B17001_040M       Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Male!!25 to 34 years
# B17001_041E              Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!35 to 44 years
# B17001_041M       Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Male!!35 to 44 years
# B17001_042E              Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!45 to 54 years
# B17001_042M       Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Male!!45 to 54 years
# B17001_043E              Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!55 to 64 years
# B17001_043M       Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Male!!55 to 64 years
# B17001_044E              Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!65 to 74 years
# B17001_044M       Margin of Error!!Total!!Income in the past 12 months at or above poverty level!!Male!!65 to 74 years
# ...                                                                                                                ...
# B17001_012E                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!35 to 44 years
# B17001_012M             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!35 to 44 years
# B17001_013E                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!45 to 54 years
# B17001_013M             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!45 to 54 years
# B17001_014E                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!55 to 64 years
# B17001_014M             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!55 to 64 years
# B17001_015M             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# B17001_015E                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# B17001_016M          Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# B17001_016E                 Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# B17001_017M                           Margin of Error!!Total!!Income in the past 12 months below poverty level!!Female
# B17001_017E                                  Estimate!!Total!!Income in the past 12 months below poverty level!!Female
# B17001_006M              Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!6 to 11 years
# B17001_006E                     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!6 to 11 years
# B17001_007M             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!12 to 14 years
# B17001_007E                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!12 to 14 years
# B17001_008M                   Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!15 years
# B17001_008E                          Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!15 years
# B17001_009M            Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!16 and 17 years
# B17001_009E                   Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!16 and 17 years
# B17001_001E                                                                                            Estimate!!Total
# B17001_001M                                                                                     Margin of Error!!Total
# B17001_002E                                          Estimate!!Total!!Income in the past 12 months below poverty level
# B17001_002M                                   Margin of Error!!Total!!Income in the past 12 months below poverty level
# B17001_003E                                    Estimate!!Total!!Income in the past 12 months below poverty level!!Male
# B17001_003M                             Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male
# B17001_004M              Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!Under 5 years
# B17001_004E                     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!Under 5 years
# B17001_005M                    Margin of Error!!Total!!Income in the past 12 months below poverty level!!Male!!5 years
# B17001_005E                           Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!5 years
#
#             limit predicateOnly predicateType
# B17001_050M     0          True           int
# B17001_050E     0          True           int
# B17001_051E     0          True           int
# B17001_051M     0          True           int
# B17001_052E     0          True           int
# B17001_052M     0          True           int
# B17001_053E     0          True           int
# B17001_053M     0          True           int
# B17001_054E     0          True           int
# B17001_054M     0          True           int
# B17001_055E     0          True           int
# B17001_055M     0          True           int
# B17001_056E     0          True           int
# B17001_056M     0          True           int
# B17001_057E     0          True           int
# B17001_057M     0          True           int
# B17001_058E     0          True           int
# B17001_058M     0          True           int
# B17001_059M     0          True           int
# B17001_059E     0          True           int
# B17001_040E     0          True           int
# B17001_040M     0          True           int
# B17001_041E     0          True           int
# B17001_041M     0          True           int
# B17001_042E     0          True           int
# B17001_042M     0          True           int
# B17001_043E     0          True           int
# B17001_043M     0          True           int
# B17001_044E     0          True           int
# B17001_044M     0          True           int
# ...           ...           ...           ...
# B17001_012E     0          True           int
# B17001_012M     0          True           int
# B17001_013E     0          True           int
# B17001_013M     0          True           int
# B17001_014E     0          True           int
# B17001_014M     0          True           int
# B17001_015M     0          True           int
# B17001_015E     0          True           int
# B17001_016M     0          True           int
# B17001_016E     0          True           int
# B17001_017M     0          True           int
# B17001_017E     0          True           int
# B17001_006M     0          True           int
# B17001_006E     0          True           int
# B17001_007M     0          True           int
# B17001_007E     0          True           int
# B17001_008M     0          True           int
# B17001_008E     0          True           int
# B17001_009M     0          True           int
# B17001_009E     0          True           int
# B17001_001E     0          True           int
# B17001_001M     0          True           int
# B17001_002E     0          True           int
# B17001_002M     0          True           int
# B17001_003E     0          True           int
# B17001_003M     0          True           int
# B17001_004M     0          True           int
# B17001_004E     0          True           int
# B17001_005M     0          True           int
# B17001_005E     0          True           int
#
# [118 rows x 6 columns]

# %% [markdown]
# ### Use the wrapper to query for your selected fields
#
# Once we've identified which fields we want, we can begin to query for the actual content
#
# There are a number of convenient methods that the wrapper provides, but the standard `get()` function requires a tuple of field IDs, and a geographic reference stored in a dictionary as seen below.
#
# In this code, we're saying we want data for these 6 fields for ALL zip codes.

# %%
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E", "B19301_001E", "B17001_002E","B25033_001E","B25033_002E"), 
                         {'for': 'zip code tabulation area:*'})

census_data[:5]
# Out:
# [{'NAME': 'ZCTA5 00601',
#   'B19013_001E': 11757.0,
#   'B01003_001E': 17599.0,
#   'B01002_001E': 38.9,
#   'B19301_001E': 7041.0,
#   'B17001_002E': 11282.0,
#   'B25033_001E': 17525.0,
#   'B25033_002E': 9779.0,
#   'zip code tabulation area': '00601'},
#  {'NAME': 'ZCTA5 00602',
#   'B19013_001E': 16190.0,
#   'B01003_001E': 39209.0,
#   'B01002_001E': 40.9,
#   'B19301_001E': 8978.0,
#   'B17001_002E': 20428.0,
#   'B25033_001E': 39116.0,
#   'B25033_002E': 30453.0,
#   'zip code tabulation area': '00602'},
#  {'NAME': 'ZCTA5 00603',
#   'B19013_001E': 16645.0,
#   'B01003_001E': 50135.0,
#   'B01002_001E': 40.4,
#   'B19301_001E': 10897.0,
#   'B17001_002E': 25176.0,
#   'B25033_001E': 48160.0,
#   'B25033_002E': 28468.0,
#   'zip code tabulation area': '00603'},
#  {'NAME': 'ZCTA5 00606',
#   'B19013_001E': 13387.0,
#   'B01003_001E': 6304.0,
#   'B01002_001E': 42.8,
#   'B19301_001E': 5960.0,
#   'B17001_002E': 4092.0,
#   'B25033_001E': 6288.0,
#   'B25033_002E': 4354.0,
#   'zip code tabulation area': '00606'},
#  {'NAME': 'ZCTA5 00610',
#   'B19013_001E': 18741.0,
#   'B01003_001E': 27590.0,
#   'B01002_001E': 41.4,
#   'B19301_001E': 9266.0,
#   'B17001_002E': 12553.0,
#   'B25033_001E': 27474.0,
#   'B25033_002E': 21493.0,
#   'zip code tabulation area': '00610'}]

# %% [markdown]
# ### Format the response

# %%
# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Renaming columns to be more user-friendly
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B25033_001E": "Total Households",
                                      "B25033_002E": "Total Owner Occupied",
                                      "NAME": "Name", 
                                      "zip code tabulation area": "Zipcode"})

# Since Census doesn't provide the poverty rate, we can divide Poverty Count by Population to calculate it ourselves
census_pd["Poverty Rate"] = 100 * census_pd["Poverty Count"].astype(int) / census_pd["Population"].astype(int)
census_pd["% Owner Occupied"] = 100 * (census_pd["Total Owner Occupied"].astype(int) / census_pd["Total Households"].astype(int))

# Reorder columns and only include ones we're interested in for the final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Rate","Total Households","Total Owner Occupied", "% Owner Occupied"]]

# Visualize
print("Total number of zip codes in response: " + str(len(census_pd)))


census_pd.head()
# Out:
# Total number of zip codes in response: 33120
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601     17599.0        38.9           11757.0             7041.0
# 1   00602     39209.0        40.9           16190.0             8978.0
# 2   00603     50135.0        40.4           16645.0            10897.0
# 3   00606      6304.0        42.8           13387.0             5960.0
# 4   00610     27590.0        41.4           18741.0             9266.0
#
#    Poverty Rate  Total Households  Total Owner Occupied  % Owner Occupied
# 0     64.105915           17525.0                9779.0         55.800285
# 1     52.100283           39116.0               30453.0         77.853052
# 2     50.216416           48160.0               28468.0         59.111296
# 3     64.911168            6288.0                4354.0         69.243003
# 4     45.498369           27474.0               21493.0         78.230327

# %%
census_pd["Zipcode"] = census_pd["Zipcode"].astype('str')

census_pd["Zip Length"]= census_pd["Zipcode"].str.len()

census_pd.dtypes

# census_pd.head()

# census_pd['Zip Length'].value_counts()
# census_pd2 = census_pd[census_pd["Zipcode" == "00601"]]

census_pd["first2"]= census_pd["Zipcode"].str.slice(0, 2, 1)

census_pd.head()

census_pd2=census_pd[census_pd["first2"] == "77"]
census_pd2=census_pd2.drop(columns=["Zip Length","first2"])
census_pd2.head()
# Out:
#       Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 26654   77002     12370.0        34.1           72306.0            34779.0
# 26655   77003      9646.0        34.1           59575.0            37760.0
# 26656   77004     37642.0        28.3           48592.0            31067.0
# 26657   77005     28233.0        36.5          180758.0           100896.0
# 26658   77006     21945.0        34.3           82878.0            68705.0
#
#        Poverty Rate  Total Households  Total Owner Occupied  % Owner Occupied
# 26654      6.984640            4457.0                1213.0         27.215616
# 26655     27.628032            9597.0                4731.0         49.296655
# 26656     19.733277           28125.0                9997.0         35.544889
# 26657      3.715510           25438.0               20433.0         80.324711
# 26658      7.304625           21280.0                8945.0         42.034774

# %% [markdown]
# ### Save to a CSV

# %%
census_pd2.to_csv("../Clean Data Files/census_data.csv", encoding="utf-8", index=False)

# %%
census_pd2.to_json("../static/data/census_data.json", orient="records")
